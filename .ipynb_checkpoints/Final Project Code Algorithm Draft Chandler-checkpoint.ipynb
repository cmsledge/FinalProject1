# %%
# !pip install -q requests
# Out:
# /bin/sh: pip: command not found

# %%
import requests
import json

# %%
def restaurant_in_syracuse():
    key= "d4dbc9b15e74cf95c8b2c635e6d83c60"
    url= "https://developers.zomato.com/api/v2.1/search?entity_id=988&entity_type=city"
    if __name__ == '__main__':
        r = requests.get(url, headers={'user-key': key})
    if r.ok:
        data = r.json()
    # Conditionals go here (coming soon)
    return data

# %%
restaurant_in_syracuse()
# Out:
# {'results_found': 1465,
#  'results_start': 0,
#  'results_shown': 20,
#  'restaurants': [{'restaurant': {'R': {'res_id': 17643027},
#     'apikey': 'd4dbc9b15e74cf95c8b2c635e6d83c60',
#     'id': '17643027',
#     'name': 'Dinosaur Bar-b-Que',
#     'url': 'https://www.zomato.com/syracuse-ny/dinosaur-bar-b-que-syracuse?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '246 West Willow Street 13202',
#      'locality': 'Syracuse',
#      'city': 'Syracuse',
#      'city_id': 988,
#      'latitude': '43.0524800000',
#      'longitude': '-76.1541400000',
#      'zipcode': '13202',
#      'country_id': 216,
#      'locality_verbose': 'Syracuse, Syracuse'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'American, BBQ, Southern',
#     'average_cost_for_two': 25,
#     'price_range': 2,
#     'currency': '$',
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
# ...

# %%
#Numbers 23 - 38 Algorithm

    if user == 'Turkish':
        return True
    if user == 'Caribbean':
        return True
    if user == 'Italian':
        return True
    if user == 'German':
        return True

        
#or is it if/elif?
#lesson 6 NYC2: http://localhost:8888/notebooks/content/lessons/06/Now-You-Code/NYC2-Course-Grade.ipynb

print("Restaurant Price Range")
price = int(input("Enter your price range out of $101"))
if price >= 101:
    restaurants = "Restaurants with meal totals above 101 "
elif price >= 90:
    restaurants = "Restaurants with meal totals from 91 - 100"
elif price >= 80:
    restaurants = "Restaurants with meal totals from 81 - 90"
elif price >= 70:
    restaurants = "Restaurants with meal totals from 71 - 80"
elif price >= 60:
    restaurants = "Restaurants with meal totals from 61 - 70 "
elif price >= 50:
    restaurants = "Restaurants with meal totals from 51 - 60"
elif price >= 40:
    restaurants = "Restaurants with meal totals from 41 - 50"
elif price >= 30:
    restaurants = "Restaurants with meal totals from 31 - 40"
elif price >= 20:
    restaurants = "Restaurants with meal totals from 21 - 30 "
elif price >= 10:
    restaurants = "Restaurants with meal totals from 11 - 20"
elif price >= 0:
    restaurants = "Restaurants with meal totals from 1 - 10"
else: price = "There are no restaurants with meals under 0"
    
print("Price:" , price)
# Out:
#   File "<ipython-input-20-0843d311cef1>", line 3
#     if user == 'Turkish':
#     ^
# IndentationError: unexpected indent

# %%
#code for cuisines list

print("Where should I take my date in Syracuse?")
cuisine = input("Enter your preferred cuisine: ")
r = restaurant_in_syracuse()


list = ['Italian' , 'Mexican' , 'Asian' , 'Japanese' , 'Chinese' , 'BBQ' , 'Southern' , 'Cuban' , 'American' ,
       'Burger' , 'Vegetarian' , 'Caribbean' , 'German' , 'Turkish' , 'Mediterranean' , 'European' , 'Seafood' , 'Steak' , 
       'Sushi' , 'Thai' , 'International' , 'Breakfast' , 'Diner' , 'Pizza' , 'Sandwich' ]
if cuisine in list:
    print(cuisine, restaurant_in_syracuse())
# Out:
# Where should I take my date in Syracuse?
# Enter your preferred cuisine: Chinese
# ...

# %%
print("Where should I take my date in Syracuse?")
cuisine = input("Enter your preferred cuisine: ")
r = restaurant_in_syracuse()


cuisine_list = []

if cuisine in list:
    print('cuisine' , 'r')
# Out:
# Where should I take my date in Syracuse?
# Enter your preferred cuisine: chinese

# %%
#code for price range

print("Enter your price range")
x = int(input("Enter low end of price range")
y = int(input("Enter high end of price range")
print(“you are looking for food in between %d and %d” % (x,y))
# Out:
#   File "<ipython-input-65-f6b52d742920>", line 5
#     y = int(input("Enter high end of price range")
#     ^
# SyntaxError: invalid syntax

# %%
#Lesson11 , Watch me code 2 Geocoding

import requests

text = 'Syracuse Cuisines and Menus'
data =  { 'q' : text, 'format' : 'json'}
url= "https://developers.zomato.com/api/v2.1/search?entity_id=988&entity_type=city"
response = requests.get(url, params=data)
print
# Out:
# <function print>

# %%
#if and for is used to conditionally print the cuisines

#we need to titelcase our inputs!
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-063c1bf11b2c> in <module>()
#       1 #if and for is used to conditionally print the cuisines
#       2
# ----> 3 restaurant_cuisine.split(',')
#
# NameError: name 'restaurant_cuisine' is not defined
